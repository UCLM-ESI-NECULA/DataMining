# %% [markdown]
# <a href="https://colab.research.google.com/github/UCLM-ESI-NECULA/DataMining/blob/master/Pandas_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
! pip install typing_extensions --upgrade

# %%
import os
os._exit(00)

# %%
import os
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

from sklearn.impute import SimpleImputer


DS1  = 'DS1-DatosConsumoAlimentario.txt'
DS2  = 'DS2-PreciosSemanales.txt'
DS3A = 'DS3A-DatosMercaMadrid.txt'
DS3B = 'DS3B-DatosMercaBarna.txt'
DS4  = 'DS4-ComercioExterior.txt'
DS5  = 'DS5-CoronavirusCases.txt'

#Folders for the transformed data
DS3Transformed = 'DS3-Transformed'

# Directory path
dir_path = '/content/drive/MyDrive/Scuola/UCLM/Colab Notebooks/DS3-Transformed/DS3-ProductData'

df = pd.read_csv(dir_path, sep='|')

profile = ProfileReport(df, title="ProductData", html={'style':{'full_width': True}})
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-11-26 18:06:18.361463&quot;&gt;&lt;title&gt;ProductData&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
